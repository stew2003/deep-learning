# %% [markdown]
# ## Anomaly detection with autoencoders
#
# In this notebook we you have to create a fully-connected neural network based autoencoder in order to detect credit card frauds. In the dataset there are 492 labeled frauds and 284807 normal transactions. First, let's download the dataset and unpack it (original source of the dataset: https://www.kaggle.com/mlg-ulb/creditcardfraud - before downloading the data please read and accept the licence of the original datasource):

# %%
# !wget https://www.deeplearningoktatas.hu/downloads/Anomaly/creditcardfraud.zip
# Out:
# --2024-05-09 14:12:54--  https://www.deeplearningoktatas.hu/downloads/Anomaly/creditcardfraud.zip
# Resolving www.deeplearningoktatas.hu (www.deeplearningoktatas.hu)... 91.227.138.51
# Connecting to www.deeplearningoktatas.hu (www.deeplearningoktatas.hu)|91.227.138.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 69155632 (66M) [application/zip]
# Saving to: ‘creditcardfraud.zip’
#
# creditcardfraud.zip 100%[===================>]  65.95M  19.9MB/s    in 3.4s
#
# 2024-05-09 14:12:58 (19.3 MB/s) - ‘creditcardfraud.zip’ saved [69155632/69155632]

# %%
# %%capture
# !unzip creditcardfraud.zip

# %% [markdown]
# ## Imports
# Import the necessary modules:

# %%
import pandas as pd #
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, Activation
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import SGD
from tensorflow.keras import regularizers
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error
np.random.seed(123)

# %% [markdown]
# ## Exercise 1: Reading and preparing the data
# Read the creditcard.csv into a Pandas Dataframe with the [read_csv](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html) function.

# %%
df = pd.read_csv("creditcard.csv")

# %% [markdown]
# As the next step, select all the columns of the dataframe for the input X, but the "Class" column. And select the "Class" column for output Y. Make sure that both X and Y are two dimensional Numpy arrays.
#
# Hint:
# * you can use df.loc to select rows and columns from a dataframe
# * you can get the Numpy array of a Pandas object with .values, eg. df['myfeature'].values

# %%
X = df.drop("Class", axis=1).values
Y = df["Class"].values

Y = np.reshape(Y, (-1, 1))

# %%
print("Shape of X:", X.shape)
print("Shape of Y:", Y.shape)
# Out:
# Shape of X: (284807, 30)
# Shape of Y: (284807, 1)

# %% [markdown]
# Let's standardize the data:

# %%
scaler = preprocessing.StandardScaler().fit(X)
X = scaler.transform(X)

# %% [markdown]
# ## Exercise 2: defining the autoencoder
# Let's define a model according to the following instructions:
# * the model's inputs and outputs should be the same as the number of X's features (columns)
# * the model should have 5 hidden layers, with 16-10-6-10-16 neurons in the hidden layers, respectively
# * all layers but the output should have tanh activation
# * the output layer should have linear activation

# %%
model = Sequential()
model.add(Dense(16, input_dim=X.shape[1], activation='tanh'))
model.add(Dense(10, activation='tanh'))
model.add(Dense(6, activation='tanh'))
model.add(Dense(10, activation='tanh'))
model.add(Dense(16, activation='tanh'))
model.add(Dense(X.shape[1], activation='linear'))

# %% [markdown]
# ## Exercise 3: define early stopping compile the model, and train it
# Please pay attention to the following details:
# * use EarlyStopping with patience 10 and this time monitor the training loss
# * do not define validation data
# * use mean squarred error loss function
# * both the input and output of the model should be X this time. (as we are "auto encoding" the input to the output)

# %%
patience = 10
es = EarlyStopping(monitor='loss', verbose=1, patience=patience, restore_best_weights=True)

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])

# %%
history= model.fit(X, X, epochs=1000, batch_size=256, callbacks=[es])
# Out:
# Epoch 1/1000
# 1113/1113 [==============================] - 1s 745us/step - loss: 0.8039 - accuracy: 0.2401
# Epoch 2/1000
# 1113/1113 [==============================] - 1s 700us/step - loss: 0.7431 - accuracy: 0.2786
# Epoch 3/1000
# 1113/1113 [==============================] - 1s 726us/step - loss: 0.6930 - accuracy: 0.3054
# Epoch 4/1000
# 1113/1113 [==============================] - 1s 694us/step - loss: 0.6735 - accuracy: 0.3247
# Epoch 5/1000
# 1113/1113 [==============================] - 1s 667us/step - loss: 0.6491 - accuracy: 0.3380
# Epoch 6/1000
# 1113/1113 [==============================] - 1s 670us/step - loss: 0.6150 - accuracy: 0.3613
# Epoch 7/1000
# 1113/1113 [==============================] - 1s 675us/step - loss: 0.5881 - accuracy: 0.3864
# Epoch 8/1000
# 1113/1113 [==============================] - 1s 684us/step - loss: 0.5716 - accuracy: 0.3902
# Epoch 9/1000
# 1113/1113 [==============================] - 1s 667us/step - loss: 0.5610 - accuracy: 0.3922
# Epoch 10/1000
# 1113/1113 [==============================] - 1s 692us/step - loss: 0.5516 - accuracy: 0.3964
# Epoch 11/1000
# 1113/1113 [==============================] - 1s 702us/step - loss: 0.5417 - accuracy: 0.4002
# Epoch 12/1000
# 1113/1113 [==============================] - 1s 687us/step - loss: 0.5328 - accuracy: 0.4037
# Epoch 13/1000
# 1113/1113 [==============================] - 1s 689us/step - loss: 0.5255 - accuracy: 0.4062
# Epoch 14/1000
# 1113/1113 [==============================] - 1s 700us/step - loss: 0.5183 - accuracy: 0.4085
# Epoch 15/1000
# 1113/1113 [==============================] - 1s 690us/step - loss: 0.5128 - accuracy: 0.4108
# Epoch 16/1000
# 1113/1113 [==============================] - 1s 764us/step - loss: 0.5087 - accuracy: 0.4127
# Epoch 17/1000
# 1113/1113 [==============================] - 1s 726us/step - loss: 0.5049 - accuracy: 0.4150
# Epoch 18/1000
# 1113/1113 [==============================] - 1s 701us/step - loss: 0.5019 - accuracy: 0.4173
# Epoch 19/1000
# 1113/1113 [==============================] - 1s 696us/step - loss: 0.4996 - accuracy: 0.4205
# Epoch 20/1000
# 1113/1113 [==============================] - 1s 701us/step - loss: 0.4977 - accuracy: 0.4222
# Epoch 21/1000
# 1113/1113 [==============================] - 1s 675us/step - loss: 0.4957 - accuracy: 0.4245
# Epoch 22/1000
# 1113/1113 [==============================] - 1s 716us/step - loss: 0.4941 - accuracy: 0.4258
# Epoch 23/1000
# 1113/1113 [==============================] - 1s 675us/step - loss: 0.4922 - accuracy: 0.4273
# Epoch 24/1000
# 1113/1113 [==============================] - 1s 688us/step - loss: 0.4925 - accuracy: 0.4288
# Epoch 25/1000
# 1113/1113 [==============================] - 1s 670us/step - loss: 0.4915 - accuracy: 0.4283
# Epoch 26/1000
# 1113/1113 [==============================] - 1s 689us/step - loss: 0.4899 - accuracy: 0.4291
# Epoch 27/1000
# 1113/1113 [==============================] - 1s 684us/step - loss: 0.4879 - accuracy: 0.4291
# Epoch 28/1000
# 1113/1113 [==============================] - 1s 681us/step - loss: 0.4866 - accuracy: 0.4301
# Epoch 29/1000
# 1113/1113 [==============================] - 1s 687us/step - loss: 0.4861 - accuracy: 0.4293
# Epoch 30/1000
# 1113/1113 [==============================] - 1s 682us/step - loss: 0.4850 - accuracy: 0.4299
# Epoch 31/1000
# 1113/1113 [==============================] - 1s 686us/step - loss: 0.4848 - accuracy: 0.4294
# Epoch 32/1000
# 1113/1113 [==============================] - 1s 687us/step - loss: 0.4829 - accuracy: 0.4295
# Epoch 33/1000
# 1113/1113 [==============================] - 1s 688us/step - loss: 0.4817 - accuracy: 0.4303
# Epoch 34/1000
# 1113/1113 [==============================] - 1s 696us/step - loss: 0.4809 - accuracy: 0.4309
# Epoch 35/1000
# 1113/1113 [==============================] - 1s 722us/step - loss: 0.4807 - accuracy: 0.4315
# Epoch 36/1000
# 1113/1113 [==============================] - 1s 695us/step - loss: 0.4791 - accuracy: 0.4323
# Epoch 37/1000
# 1113/1113 [==============================] - 1s 698us/step - loss: 0.4786 - accuracy: 0.4325
# Epoch 38/1000
# 1113/1113 [==============================] - 1s 695us/step - loss: 0.4783 - accuracy: 0.4332
# Epoch 39/1000
# 1113/1113 [==============================] - 1s 714us/step - loss: 0.4774 - accuracy: 0.4340
# Epoch 40/1000
# 1113/1113 [==============================] - 1s 717us/step - loss: 0.4767 - accuracy: 0.4343
# Epoch 41/1000
# 1113/1113 [==============================] - 1s 717us/step - loss: 0.4762 - accuracy: 0.4344
# Epoch 42/1000
# 1113/1113 [==============================] - 1s 708us/step - loss: 0.4757 - accuracy: 0.4335
# Epoch 43/1000
# 1113/1113 [==============================] - 1s 727us/step - loss: 0.4755 - accuracy: 0.4345
# Epoch 44/1000
# 1113/1113 [==============================] - 1s 694us/step - loss: 0.4752 - accuracy: 0.4341
# Epoch 45/1000
# 1113/1113 [==============================] - 1s 714us/step - loss: 0.4744 - accuracy: 0.4347
# Epoch 46/1000
# 1113/1113 [==============================] - 1s 701us/step - loss: 0.4744 - accuracy: 0.4346
# Epoch 47/1000
# 1113/1113 [==============================] - 1s 703us/step - loss: 0.4744 - accuracy: 0.4345
# Epoch 48/1000
# 1113/1113 [==============================] - 1s 728us/step - loss: 0.4731 - accuracy: 0.4343
# Epoch 49/1000
# 1113/1113 [==============================] - 1s 730us/step - loss: 0.4726 - accuracy: 0.4344
# Epoch 50/1000
# 1113/1113 [==============================] - 1s 788us/step - loss: 0.4727 - accuracy: 0.4347
# Epoch 51/1000
# 1113/1113 [==============================] - 1s 758us/step - loss: 0.4720 - accuracy: 0.4340
# Epoch 52/1000
# 1113/1113 [==============================] - 1s 675us/step - loss: 0.4723 - accuracy: 0.4339
# Epoch 53/1000
# 1113/1113 [==============================] - 1s 691us/step - loss: 0.4719 - accuracy: 0.4343
# Epoch 54/1000
# 1113/1113 [==============================] - 1s 685us/step - loss: 0.4713 - accuracy: 0.4338
# Epoch 55/1000
# 1113/1113 [==============================] - 1s 675us/step - loss: 0.4710 - accuracy: 0.4335
# Epoch 56/1000
# 1113/1113 [==============================] - 1s 676us/step - loss: 0.4712 - accuracy: 0.4339
# Epoch 57/1000
# 1113/1113 [==============================] - 1s 685us/step - loss: 0.4706 - accuracy: 0.4337
# Epoch 58/1000
# 1113/1113 [==============================] - 1s 692us/step - loss: 0.4699 - accuracy: 0.4334
# Epoch 59/1000
# 1113/1113 [==============================] - 1s 685us/step - loss: 0.4705 - accuracy: 0.4332
# Epoch 60/1000
# 1113/1113 [==============================] - 1s 673us/step - loss: 0.4706 - accuracy: 0.4328
# Epoch 61/1000
# 1113/1113 [==============================] - 1s 680us/step - loss: 0.4700 - accuracy: 0.4327
# Epoch 62/1000
# 1113/1113 [==============================] - 1s 692us/step - loss: 0.4693 - accuracy: 0.4331
# Epoch 63/1000
# 1113/1113 [==============================] - 1s 728us/step - loss: 0.4691 - accuracy: 0.4326
# Epoch 64/1000
# 1113/1113 [==============================] - 1s 695us/step - loss: 0.4690 - accuracy: 0.4324
# Epoch 65/1000
# 1113/1113 [==============================] - 1s 703us/step - loss: 0.4687 - accuracy: 0.4323
# Epoch 66/1000
# 1113/1113 [==============================] - 1s 718us/step - loss: 0.4690 - accuracy: 0.4323
# Epoch 67/1000
# 1113/1113 [==============================] - 1s 718us/step - loss: 0.4688 - accuracy: 0.4326
# Epoch 68/1000
# 1113/1113 [==============================] - 1s 703us/step - loss: 0.4681 - accuracy: 0.4321
# Epoch 69/1000
# 1113/1113 [==============================] - 1s 682us/step - loss: 0.4684 - accuracy: 0.4324
# Epoch 70/1000
# 1113/1113 [==============================] - 1s 670us/step - loss: 0.4676 - accuracy: 0.4321
# Epoch 71/1000
# 1113/1113 [==============================] - 1s 671us/step - loss: 0.4677 - accuracy: 0.4321
# Epoch 72/1000
# 1113/1113 [==============================] - 1s 674us/step - loss: 0.4676 - accuracy: 0.4322
# Epoch 73/1000
# 1113/1113 [==============================] - 1s 681us/step - loss: 0.4680 - accuracy: 0.4322
# Epoch 74/1000
# 1113/1113 [==============================] - 1s 697us/step - loss: 0.4676 - accuracy: 0.4321
# Epoch 75/1000
# 1113/1113 [==============================] - 1s 715us/step - loss: 0.4668 - accuracy: 0.4323
# Epoch 76/1000
# 1113/1113 [==============================] - 1s 704us/step - loss: 0.4666 - accuracy: 0.4321
# Epoch 77/1000
# 1113/1113 [==============================] - 1s 693us/step - loss: 0.4661 - accuracy: 0.4325
# Epoch 78/1000
# 1113/1113 [==============================] - 1s 718us/step - loss: 0.4665 - accuracy: 0.4321
# Epoch 79/1000
# 1113/1113 [==============================] - 1s 689us/step - loss: 0.4663 - accuracy: 0.4329
# Epoch 80/1000
# 1113/1113 [==============================] - 1s 685us/step - loss: 0.4660 - accuracy: 0.4328
# Epoch 81/1000
# 1113/1113 [==============================] - 1s 690us/step - loss: 0.4658 - accuracy: 0.4328
# Epoch 82/1000
# 1113/1113 [==============================] - 1s 712us/step - loss: 0.4656 - accuracy: 0.4332
# Epoch 83/1000
# 1113/1113 [==============================] - 1s 676us/step - loss: 0.4663 - accuracy: 0.4330
# Epoch 84/1000
# 1113/1113 [==============================] - 1s 678us/step - loss: 0.4651 - accuracy: 0.4337
# Epoch 85/1000
# 1113/1113 [==============================] - 1s 737us/step - loss: 0.4664 - accuracy: 0.4331
# Epoch 86/1000
# 1113/1113 [==============================] - 1s 727us/step - loss: 0.4650 - accuracy: 0.4332
# Epoch 87/1000
# 1113/1113 [==============================] - 1s 699us/step - loss: 0.4647 - accuracy: 0.4331
# Epoch 88/1000
# 1113/1113 [==============================] - 1s 685us/step - loss: 0.4649 - accuracy: 0.4338
# Epoch 89/1000
# 1113/1113 [==============================] - 1s 687us/step - loss: 0.4648 - accuracy: 0.4335
# Epoch 90/1000
# 1113/1113 [==============================] - 1s 687us/step - loss: 0.4644 - accuracy: 0.4340
# Epoch 91/1000
# 1113/1113 [==============================] - 1s 681us/step - loss: 0.4647 - accuracy: 0.4335
# Epoch 92/1000
# 1113/1113 [==============================] - 1s 697us/step - loss: 0.4639 - accuracy: 0.4343
# Epoch 93/1000
# 1113/1113 [==============================] - 1s 760us/step - loss: 0.4640 - accuracy: 0.4337
# Epoch 94/1000
# 1113/1113 [==============================] - 1s 759us/step - loss: 0.4643 - accuracy: 0.4341
# Epoch 95/1000
# 1113/1113 [==============================] - 1s 703us/step - loss: 0.4636 - accuracy: 0.4340
# Epoch 96/1000
# 1113/1113 [==============================] - 1s 689us/step - loss: 0.4640 - accuracy: 0.4346
# Epoch 97/1000
# 1113/1113 [==============================] - 1s 675us/step - loss: 0.4638 - accuracy: 0.4343
# Epoch 98/1000
# 1113/1113 [==============================] - 1s 687us/step - loss: 0.4644 - accuracy: 0.4342
# Epoch 99/1000
# 1113/1113 [==============================] - 1s 675us/step - loss: 0.4631 - accuracy: 0.4346
# Epoch 100/1000
# 1113/1113 [==============================] - 1s 679us/step - loss: 0.4643 - accuracy: 0.4343
# Epoch 101/1000
# 1113/1113 [==============================] - 1s 671us/step - loss: 0.4632 - accuracy: 0.4347
# Epoch 102/1000
# 1113/1113 [==============================] - 1s 673us/step - loss: 0.4628 - accuracy: 0.4353
# Epoch 103/1000
# 1113/1113 [==============================] - 1s 671us/step - loss: 0.4638 - accuracy: 0.4341
# Epoch 104/1000
# 1113/1113 [==============================] - 1s 674us/step - loss: 0.4629 - accuracy: 0.4348
# Epoch 105/1000
# 1113/1113 [==============================] - 1s 680us/step - loss: 0.4626 - accuracy: 0.4349
# Epoch 106/1000
# 1113/1113 [==============================] - 1s 677us/step - loss: 0.4627 - accuracy: 0.4347
# Epoch 107/1000
# 1113/1113 [==============================] - 1s 676us/step - loss: 0.4631 - accuracy: 0.4352
# Epoch 108/1000
# 1113/1113 [==============================] - 1s 675us/step - loss: 0.4622 - accuracy: 0.4351
# Epoch 109/1000
# 1113/1113 [==============================] - 1s 671us/step - loss: 0.4627 - accuracy: 0.4351
# Epoch 110/1000
# 1113/1113 [==============================] - 1s 674us/step - loss: 0.4620 - accuracy: 0.4353
# Epoch 111/1000
# 1113/1113 [==============================] - 1s 685us/step - loss: 0.4625 - accuracy: 0.4356
# Epoch 112/1000
# 1113/1113 [==============================] - 1s 682us/step - loss: 0.4613 - accuracy: 0.4356
# Epoch 113/1000
# 1113/1113 [==============================] - 1s 674us/step - loss: 0.4615 - accuracy: 0.4357
# Epoch 114/1000
# 1113/1113 [==============================] - 1s 683us/step - loss: 0.4611 - accuracy: 0.4359
# Epoch 115/1000
# 1113/1113 [==============================] - 1s 668us/step - loss: 0.4617 - accuracy: 0.4352
# Epoch 116/1000
# 1113/1113 [==============================] - 1s 668us/step - loss: 0.4616 - accuracy: 0.4357
# Epoch 117/1000
# 1113/1113 [==============================] - 1s 688us/step - loss: 0.4618 - accuracy: 0.4358
# Epoch 118/1000
# 1113/1113 [==============================] - 1s 718us/step - loss: 0.4612 - accuracy: 0.4355
# Epoch 119/1000
# 1113/1113 [==============================] - 1s 784us/step - loss: 0.4618 - accuracy: 0.4350
# Epoch 120/1000
# 1113/1113 [==============================] - 1s 726us/step - loss: 0.4610 - accuracy: 0.4356
# Epoch 121/1000
# 1113/1113 [==============================] - 1s 692us/step - loss: 0.4608 - accuracy: 0.4354
# Epoch 122/1000
# 1113/1113 [==============================] - 1s 696us/step - loss: 0.4610 - accuracy: 0.4350
# Epoch 123/1000
# 1113/1113 [==============================] - 1s 691us/step - loss: 0.4603 - accuracy: 0.4361
# Epoch 124/1000
# 1113/1113 [==============================] - 1s 689us/step - loss: 0.4608 - accuracy: 0.4358
# Epoch 125/1000
# 1113/1113 [==============================] - 1s 690us/step - loss: 0.4605 - accuracy: 0.4358
# Epoch 126/1000
# 1113/1113 [==============================] - 1s 680us/step - loss: 0.4612 - accuracy: 0.4360
# Epoch 127/1000
# 1113/1113 [==============================] - 1s 674us/step - loss: 0.4635 - accuracy: 0.4355
# Epoch 128/1000
# 1113/1113 [==============================] - 1s 674us/step - loss: 0.4602 - accuracy: 0.4362
# Epoch 129/1000
# 1113/1113 [==============================] - 1s 673us/step - loss: 0.4602 - accuracy: 0.4365
# Epoch 130/1000
# 1113/1113 [==============================] - 1s 702us/step - loss: 0.4603 - accuracy: 0.4357
# Epoch 131/1000
# 1113/1113 [==============================] - 1s 684us/step - loss: 0.4602 - accuracy: 0.4364
# Epoch 132/1000
# 1113/1113 [==============================] - 1s 672us/step - loss: 0.4603 - accuracy: 0.4362
# Epoch 133/1000
# 1113/1113 [==============================] - 1s 698us/step - loss: 0.4598 - accuracy: 0.4363
# Epoch 134/1000
# 1113/1113 [==============================] - 1s 684us/step - loss: 0.4610 - accuracy: 0.4359
# Epoch 135/1000
# 1113/1113 [==============================] - 1s 700us/step - loss: 0.4605 - accuracy: 0.4362
# Epoch 136/1000
# 1113/1113 [==============================] - 1s 668us/step - loss: 0.4616 - accuracy: 0.4358
# Epoch 137/1000
# 1113/1113 [==============================] - 1s 669us/step - loss: 0.4592 - accuracy: 0.4364
# Epoch 138/1000
# 1113/1113 [==============================] - 1s 673us/step - loss: 0.4594 - accuracy: 0.4365
# Epoch 139/1000
# 1113/1113 [==============================] - 1s 672us/step - loss: 0.4599 - accuracy: 0.4362
# Epoch 140/1000
# 1113/1113 [==============================] - 1s 669us/step - loss: 0.4594 - accuracy: 0.4365
# Epoch 141/1000
# 1113/1113 [==============================] - 1s 708us/step - loss: 0.4592 - accuracy: 0.4367
# Epoch 142/1000
# 1113/1113 [==============================] - 1s 785us/step - loss: 0.4594 - accuracy: 0.4361
# Epoch 143/1000
# 1113/1113 [==============================] - 1s 741us/step - loss: 0.4609 - accuracy: 0.4356
# Epoch 144/1000
# 1113/1113 [==============================] - 1s 690us/step - loss: 0.4589 - accuracy: 0.4369
# Epoch 145/1000
# 1113/1113 [==============================] - 1s 679us/step - loss: 0.4591 - accuracy: 0.4372
# Epoch 146/1000
# 1113/1113 [==============================] - 1s 675us/step - loss: 0.4597 - accuracy: 0.4364
# Epoch 147/1000
# 1113/1113 [==============================] - 1s 668us/step - loss: 0.4586 - accuracy: 0.4363
# Epoch 148/1000
# 1113/1113 [==============================] - 1s 673us/step - loss: 0.4585 - accuracy: 0.4371
# Epoch 149/1000
# 1113/1113 [==============================] - 1s 698us/step - loss: 0.4593 - accuracy: 0.4364
# Epoch 150/1000
# 1113/1113 [==============================] - 1s 695us/step - loss: 0.4591 - accuracy: 0.4360
# Epoch 151/1000
# 1113/1113 [==============================] - 1s 688us/step - loss: 0.4580 - accuracy: 0.4370
# Epoch 152/1000
# 1113/1113 [==============================] - 1s 676us/step - loss: 0.4583 - accuracy: 0.4360
# Epoch 153/1000
# 1113/1113 [==============================] - 1s 682us/step - loss: 0.4587 - accuracy: 0.4366
# Epoch 154/1000
# 1113/1113 [==============================] - 1s 727us/step - loss: 0.4587 - accuracy: 0.4368
# Epoch 155/1000
# 1113/1113 [==============================] - 1s 751us/step - loss: 0.4590 - accuracy: 0.4366
# Epoch 156/1000
# 1113/1113 [==============================] - 1s 756us/step - loss: 0.4583 - accuracy: 0.4366
# Epoch 157/1000
# 1113/1113 [==============================] - 1s 695us/step - loss: 0.4589 - accuracy: 0.4369
# Epoch 158/1000
# 1113/1113 [==============================] - 1s 678us/step - loss: 0.4588 - accuracy: 0.4362
# Epoch 159/1000
# 1113/1113 [==============================] - 1s 680us/step - loss: 0.4576 - accuracy: 0.4365
# Epoch 160/1000
# 1113/1113 [==============================] - 1s 672us/step - loss: 0.4601 - accuracy: 0.4370
# Epoch 161/1000
# 1113/1113 [==============================] - 1s 683us/step - loss: 0.4576 - accuracy: 0.4369
# Epoch 162/1000
# 1113/1113 [==============================] - 1s 680us/step - loss: 0.4582 - accuracy: 0.4363
# Epoch 163/1000
# 1113/1113 [==============================] - 1s 699us/step - loss: 0.4602 - accuracy: 0.4357
# Epoch 164/1000
# 1113/1113 [==============================] - 1s 715us/step - loss: 0.4577 - accuracy: 0.4367
# Epoch 165/1000
# 1113/1113 [==============================] - 1s 757us/step - loss: 0.4577 - accuracy: 0.4365
# Epoch 166/1000
# 1113/1113 [==============================] - 1s 694us/step - loss: 0.4587 - accuracy: 0.4364
# Epoch 167/1000
# 1113/1113 [==============================] - 1s 728us/step - loss: 0.4582 - accuracy: 0.4361
# Epoch 168/1000
# 1113/1113 [==============================] - 1s 717us/step - loss: 0.4589 - accuracy: 0.4367
# Epoch 169/1000
# 1113/1113 [==============================] - 1s 728us/step - loss: 0.4585 - accuracy: 0.4365
# Epoch 170/1000
# 1113/1113 [==============================] - 1s 700us/step - loss: 0.4576 - accuracy: 0.4370
# Epoch 171/1000
# 1076/1113 [============================>.] - ETA: 0s - loss: 0.4611 - accuracy: 0.4366Restoring model weights from the end of the best epoch: 161.
# 1113/1113 [==============================] - 1s 704us/step - loss: 0.4601 - accuracy: 0.4369
# Epoch 171: early stopping

# %% [markdown]
# ## Results analysis
# After training is done, we make predictions for the complete dataset and inspect the reconstruction loss. Our assumption is that, higher reconstruction loss are more likely to belong to anomalies than lower reconstruciton loss.

# %%
preds = model.predict(X)
errs  = np.square(preds-X)
errs  = np.mean(errs,axis=1)
# Out:
# 8901/8901 [==============================] - 3s 355us/step

# %%
plt.figure(figsize=(16,10))
rng = np.arange(len(errs))
colors = ['g','r'] # green: normal, red: anomaly
for i in [0,1]:
    plt.scatter(rng[(Y==i).reshape(-1)], errs[(Y==i).reshape(-1)], color=colors[i])

# %%
Y_cut    = Y[errs<10]
errs_cut = errs[errs<10]

# %%
plt.figure(figsize=(16,10))
rng = np.arange(len(errs_cut))
colors = ['g','r']
for i in [0,1]:
    plt.scatter(rng[(Y_cut==i).reshape(-1)], errs_cut[(Y_cut==i).reshape(-1)], color=colors[i])

# %% [markdown]
# ## Exercise 4: finding the right treshold
# Find a treshold that identifies at least 130 anomalies correctly with as small number of missclassifications of non-anomalies as possible.

# %%
treshold = 3.1
errs_filtered               = errs[errs>treshold]
Y_filtered                  = Y[errs>treshold, 0]
errs_filtered_non_anomalies = errs[errs<=treshold]
Y_filtered_non_anomalies    = Y[errs<=treshold, 0]

print("Anomalies in the dataset") # Y_filtered==1
print("   predicted as anomaly:", len(errs_filtered[Y_filtered==1]))
print("   predicted as non-anomaly: ", len(errs_filtered_non_anomalies[Y_filtered_non_anomalies==1]) )
print("Non-anomalies in the dataset") # Y_filtered ==0
print("   predicted as anomaly:", len(errs_filtered[Y_filtered==0]))
print("   predicted as non-anomaly:", len(errs_filtered_non_anomalies[Y_filtered_non_anomalies==0]) )
# Out:
# Anomalies in the dataset
#    predicted as anomaly: 137
#    predicted as non-anomaly:  355
# Non-anomalies in the dataset
#    predicted as anomaly: 3283
#    predicted as non-anomaly: 281032

# %% [markdown]
# We can also inspect the confusion matrix:

# %%
from sklearn.metrics import confusion_matrix
conf=confusion_matrix(Y, errs>treshold)
import seaborn as sns
sns.heatmap(conf, annot=True, vmax=8000, fmt="d")
# Out:
# <Axes: >
